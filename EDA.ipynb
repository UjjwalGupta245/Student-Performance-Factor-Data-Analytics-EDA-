# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-34ff3e09-3b9a-4299-8896-68356f8ca498" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-34ff3e09-3b9a-4299-8896-68356f8ca498">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df=pd.read_csv('StudentPerformanceFactors.csv')

# %%
df
# Out:
#       Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 0                23          84                  Low                High
# 1                19          64                  Low              Medium
# 2                24          98               Medium              Medium
# 3                29          89                  Low              Medium
# 4                19          92               Medium              Medium
# ...             ...         ...                  ...                 ...
# 6602             25          69                 High              Medium
# 6603             23          76                 High              Medium
# 6604             20          90               Medium                 Low
# 6605             10          86                 High                High
# 6606             15          67               Medium                 Low
#
#      Extracurricular_Activities  Sleep_Hours  Previous_Scores  \
# ...

# %%
df.head(5)
# Out:
#    Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 0             23          84                  Low                High
# 1             19          64                  Low              Medium
# 2             24          98               Medium              Medium
# 3             29          89                  Low              Medium
# 4             19          92               Medium              Medium
#
#   Extracurricular_Activities  Sleep_Hours  Previous_Scores Motivation_Level  \
# 0                         No            7               73              Low
# 1                         No            8               59              Low
# 2                        Yes            7               91           Medium
# 3                        Yes            8               98           Medium
# 4                        Yes            6               65           Medium
#
#   Internet_Access  Tutoring_Sessions Family_Income Teacher_Quality  \
# ...

# %%
df.describe(include ='all')
# Out:
#         Hours_Studied   Attendance Parental_Involvement Access_to_Resources  \
# count     6607.000000  6607.000000                 6607                6607
# unique            NaN          NaN                    3                   3
# top               NaN          NaN               Medium              Medium
# freq              NaN          NaN                 3362                3319
# mean        19.975329    79.977448                  NaN                 NaN
# std          5.990594    11.547475                  NaN                 NaN
# min          1.000000    60.000000                  NaN                 NaN
# 25%         16.000000    70.000000                  NaN                 NaN
# 50%         20.000000    80.000000                  NaN                 NaN
# 75%         24.000000    90.000000                  NaN                 NaN
# max         44.000000   100.000000                  NaN                 NaN
#
# ...

# %%
plt.subplot(221)
df['Hours_Studied'].value_counts().plot(kind='bar',title='Hours_Studied',figsize=(20,10))
plt.xticks(rotation=0)
plt.subplot(222)
df['Attendance'].value_counts().plot(kind='bar',title='Attendance',figsize=(20,10))
plt.xticks(rotation=0)
plt.subplot(223)
df['Parental_Involvement'].value_counts().plot(kind='bar',title='Parental_Involvement',figsize=(20,10))
plt.xticks(rotation=0)
plt.subplot(224)
df['Access_to_Resources'].value_counts().plot(kind='bar',title='Access_to_Resources',figsize=(20,10))
plt.xticks(rotation=0)
# Out:
# (array([0, 1, 2]),
#  [Text(0, 0, 'Medium'), Text(1, 0, 'High'), Text(2, 0, 'Low')])

# %%
df.boxplot()
# Out:
# <Axes: >

# %%
sns.histplot(df['Hours_Studied'])
# Out:
# <Axes: xlabel='Hours_Studied', ylabel='Count'>

# %%
df.tail(10)
# Out:
#       Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 6597             16          91                 High              Medium
# 6598              9          87                  Low              Medium
# 6599             30          94               Medium                 Low
# 6600             12          98               Medium                 Low
# 6601             20          83               Medium                 Low
# 6602             25          69                 High              Medium
# 6603             23          76                 High              Medium
# 6604             20          90               Medium                 Low
# 6605             10          86                 High                High
# 6606             15          67               Medium                 Low
#
#      Extracurricular_Activities  Sleep_Hours  Previous_Scores  \
# 6597                        Yes            6               72
# ...

# %%
sns.distplot(df['Exam_Score'])
# Out:
# <ipython-input-26-361fcc66927f>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Exam_Score'])
# <Axes: xlabel='Exam_Score', ylabel='Density'>

# %%
sns.distplot(df['Hours_Studied'])
# Out:
# <ipython-input-27-94b96f294c96>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Hours_Studied'])
# <Axes: xlabel='Hours_Studied', ylabel='Density'>

# %%
corr = df.corr(numeric_only=True)
sns.heatmap(corr,annot=True,square=True)
plt.yticks(rotation=0)
# Out:
# (array([0.5, 1.5, 2.5, 3.5, 4.5, 5.5, 6.5]),
#  [Text(0, 0.5, 'Hours_Studied'),
#   Text(0, 1.5, 'Attendance'),
#   Text(0, 2.5, 'Sleep_Hours'),
#   Text(0, 3.5, 'Previous_Scores'),
#   Text(0, 4.5, 'Tutoring_Sessions'),
#   Text(0, 5.5, 'Physical_Activity'),
#   Text(0, 6.5, 'Exam_Score')])
